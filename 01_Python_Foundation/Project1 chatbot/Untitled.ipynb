# %%
print("Data Science is ready!")
# Out:
# Data Science is ready!

# %%
import pandas as pd

# %%
data = {
    "Color": ["Blue", "Green", "Purple", "Red"],
    "Rating": [10, 8, 9, 6]
}

df = pd.DataFrame(data)
df
# Out:
#     Color  Rating
# 0    Blue      10
# 1   Green       8
# 2  Purple       9
# 3     Red       6

# %%
# Create a dummy CSV file for practice
csv_content = """user_message,bot_reply,user_rating
hello,Hello there!,5
what is ai?,AI is artificial intelligence.,4
tell me a joke,Why did the robot cross the road?,5
bad bot,I am sorry to hear that.,1
help me,How can I assist you?,4"""

with open("ai_logs.csv", "w") as f:
    f.write(csv_content)

print("ai_logs.csv created successfully!")
# Out:
# ai_logs.csv created successfully!

# %%
logs = pd.read_csv('ai_logs.csv')

# %%
print(logs)
# Out:
#      user_message                          bot_reply  user_rating
# 0           hello                       Hello there!            5
# 1     what is ai?     AI is artificial intelligence.            4
# 2  tell me a joke  Why did the robot cross the road?            5
# 3         bad bot           I am sorry to hear that.            1
# 4         help me              How can I assist you?            4

# %%
logs
# Out:
#      user_message                          bot_reply  user_rating
# 0           hello                       Hello there!            5
# 1     what is ai?     AI is artificial intelligence.            4
# 2  tell me a joke  Why did the robot cross the road?            5
# 3         bad bot           I am sorry to hear that.            1
# 4         help me              How can I assist you?            4
